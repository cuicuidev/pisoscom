# %% [markdown]
# # PISOS.COM
# - https://www.pisos.com/

# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

from time import sleep

# %%
# Compruebo si se puede hacer Web Scrapping en esta web

provincias = ["a_coruna", "alava_araba", "albacete", "alicante", "almeria", "andorra", "asturias", "avila", "badajoz",
              "islas_baleares_illes_balears", "barcelona", "bilbao", "vizcaya_bizkaia", "burgos", "caceres", "cadiz",
              "cantabria", "castellon_castello", "cerdanya_francesa", "ceuta", "ciudad_real", "cordoba", "cuenca",
              "san_sebastian_donostia", "isla_de_ibiza_eivissa", "el_hierro", "formentera", "fuerteventura",
              "vitoria_gasteiz_zona_urbana", "gijon_concejo_xixon_conceyu_gijon", "guipuzcoa_gipuzkoa", ""]

web = "https://www.pisos.com/venta/pisos-madrid/"

response = requests.get(web)
soup = BeautifulSoup(response.text, "html.parser")

response.status_code
# Out:
# 200

# %%
# %%time

# Llenamos la lista de URLs sin saber cuántas páginas son en total

urls_paginas = [web]
cont = 2
pag = 2

while True:
    
    url = f"{web}{pag}"
    response = requests.get(url)
    
    if response.url in urls_paginas:
        break
    
    urls_paginas.append(url)
    
    print(f"Página {cont} - TERMINADA")
    
    pag += 1
    cont += 1
    
    sleep(1)
# Out:
# Página 1 TERMINADA
# Página 2 TERMINADA
# Página 3 TERMINADA
# Página 4 TERMINADA
# Página 5 TERMINADA
# Página 6 TERMINADA
# Página 7 TERMINADA
# Página 8 TERMINADA
# Página 9 TERMINADA
# Página 10 TERMINADA
# Página 11 TERMINADA
# Página 12 TERMINADA
# Página 13 TERMINADA
# Página 14 TERMINADA
# Página 15 TERMINADA
# Página 16 TERMINADA
# Página 17 TERMINADA
# Página 18 TERMINADA
# Página 19 TERMINADA
# Página 20 TERMINADA
# Página 21 TERMINADA
# Página 22 TERMINADA
# Página 23 TERMINADA
# Página 24 TERMINADA
# Página 25 TERMINADA
# Página 26 TERMINADA
# Página 27 TERMINADA
# Página 28 TERMINADA
# Página 29 TERMINADA
# Página 30 TERMINADA
# Página 31 TERMINADA
# Página 32 TERMINADA
# Página 33 TERMINADA
# Página 34 TERMINADA
# Página 35 TERMINADA
# Página 36 TERMINADA
# Página 37 TERMINADA
# Página 38 TERMINADA
# Página 39 TERMINADA
# Página 40 TERMINADA
# Página 41 TERMINADA
# Página 42 TERMINADA
# Página 43 TERMINADA
# Página 44 TERMINADA
# Página 45 TERMINADA
# Página 46 TERMINADA
# Página 47 TERMINADA
# Página 48 TERMINADA
# Página 49 TERMINADA
# Página 50 TERMINADA
# Página 51 TERMINADA
# Página 52 TERMINADA
# Página 53 TERMINADA
# Página 54 TERMINADA
# Página 55 TERMINADA
# Página 56 TERMINADA
# Página 57 TERMINADA
# Página 58 TERMINADA
# Página 59 TERMINADA
# Página 60 TERMINADA
# Página 61 TERMINADA
# Página 62 TERMINADA
# Página 63 TERMINADA
# Página 64 TERMINADA
# Página 65 TERMINADA
# Página 66 TERMINADA
# Página 67 TERMINADA
# Página 68 TERMINADA
# Página 69 TERMINADA
# Página 70 TERMINADA
# Página 71 TERMINADA
# Página 72 TERMINADA
# Página 73 TERMINADA
# Página 74 TERMINADA
# Página 75 TERMINADA
# Página 76 TERMINADA
# Página 77 TERMINADA
# Página 78 TERMINADA
# Página 79 TERMINADA
# Página 80 TERMINADA
# Página 81 TERMINADA
# Página 82 TERMINADA
# Página 83 TERMINADA
# Página 84 TERMINADA
# Página 85 TERMINADA
# Página 86 TERMINADA
# Página 87 TERMINADA
# Página 88 TERMINADA
# Página 89 TERMINADA
# Página 90 TERMINADA
# Página 91 TERMINADA
# Página 92 TERMINADA
# Página 93 TERMINADA
# Página 94 TERMINADA
# Página 95 TERMINADA
# Página 96 TERMINADA
# Página 97 TERMINADA
# Página 98 TERMINADA
# Página 99 TERMINADA
# CPU times: total: 5.78 s
# Wall time: 3min 38s

# %%
urls_paginas
# Out:
# ['https://www.pisos.com/venta/pisos-madrid/',
#  'https://www.pisos.com/venta/pisos-madrid/2',
#  'https://www.pisos.com/venta/pisos-madrid/3',
#  'https://www.pisos.com/venta/pisos-madrid/4',
#  'https://www.pisos.com/venta/pisos-madrid/5',
#  'https://www.pisos.com/venta/pisos-madrid/6',
#  'https://www.pisos.com/venta/pisos-madrid/7',
#  'https://www.pisos.com/venta/pisos-madrid/8',
#  'https://www.pisos.com/venta/pisos-madrid/9',
#  'https://www.pisos.com/venta/pisos-madrid/10',
#  'https://www.pisos.com/venta/pisos-madrid/11',
#  'https://www.pisos.com/venta/pisos-madrid/12',
#  'https://www.pisos.com/venta/pisos-madrid/13',
#  'https://www.pisos.com/venta/pisos-madrid/14',
#  'https://www.pisos.com/venta/pisos-madrid/15',
#  'https://www.pisos.com/venta/pisos-madrid/16',
#  'https://www.pisos.com/venta/pisos-madrid/17',
#  'https://www.pisos.com/venta/pisos-madrid/18',
#  'https://www.pisos.com/venta/pisos-madrid/19',
#  'https://www.pisos.com/venta/pisos-madrid/20',
#  'https://www.pisos.com/venta/pisos-madrid/21',
#  'https://www.pisos.com/venta/pisos-madrid/22',
#  'https://www.pisos.com/venta/pisos-madrid/23',
#  'https://www.pisos.com/venta/pisos-madrid/24',
#  'https://www.pisos.com/venta/pisos-madrid/25',
#  'https://www.pisos.com/venta/pisos-madrid/26',
#  'https://www.pisos.com/venta/pisos-madrid/27',
#  'https://www.pisos.com/venta/pisos-madrid/28',
#  'https://www.pisos.com/venta/pisos-madrid/29',
#  'https://www.pisos.com/venta/pisos-madrid/30',
#  'https://www.pisos.com/venta/pisos-madrid/31',
#  'https://www.pisos.com/venta/pisos-madrid/32',
#  'https://www.pisos.com/venta/pisos-madrid/33',
#  'https://www.pisos.com/venta/pisos-madrid/34',
#  'https://www.pisos.com/venta/pisos-madrid/35',
#  'https://www.pisos.com/venta/pisos-madrid/36',
#  'https://www.pisos.com/venta/pisos-madrid/37',
#  'https://www.pisos.com/venta/pisos-madrid/38',
#  'https://www.pisos.com/venta/pisos-madrid/39',
#  'https://www.pisos.com/venta/pisos-madrid/40',
#  'https://www.pisos.com/venta/pisos-madrid/41',
#  'https://www.pisos.com/venta/pisos-madrid/42',
#  'https://www.pisos.com/venta/pisos-madrid/43',
#  'https://www.pisos.com/venta/pisos-madrid/44',
#  'https://www.pisos.com/venta/pisos-madrid/45',
#  'https://www.pisos.com/venta/pisos-madrid/46',
#  'https://www.pisos.com/venta/pisos-madrid/47',
#  'https://www.pisos.com/venta/pisos-madrid/48',
#  'https://www.pisos.com/venta/pisos-madrid/49',
#  'https://www.pisos.com/venta/pisos-madrid/50',
#  'https://www.pisos.com/venta/pisos-madrid/51',
#  'https://www.pisos.com/venta/pisos-madrid/52',
#  'https://www.pisos.com/venta/pisos-madrid/53',
#  'https://www.pisos.com/venta/pisos-madrid/54',
#  'https://www.pisos.com/venta/pisos-madrid/55',
#  'https://www.pisos.com/venta/pisos-madrid/56',
#  'https://www.pisos.com/venta/pisos-madrid/57',
#  'https://www.pisos.com/venta/pisos-madrid/58',
#  'https://www.pisos.com/venta/pisos-madrid/59',
#  'https://www.pisos.com/venta/pisos-madrid/60',
#  'https://www.pisos.com/venta/pisos-madrid/61',
#  'https://www.pisos.com/venta/pisos-madrid/62',
#  'https://www.pisos.com/venta/pisos-madrid/63',
#  'https://www.pisos.com/venta/pisos-madrid/64',
#  'https://www.pisos.com/venta/pisos-madrid/65',
#  'https://www.pisos.com/venta/pisos-madrid/66',
#  'https://www.pisos.com/venta/pisos-madrid/67',
#  'https://www.pisos.com/venta/pisos-madrid/68',
#  'https://www.pisos.com/venta/pisos-madrid/69',
#  'https://www.pisos.com/venta/pisos-madrid/70',
#  'https://www.pisos.com/venta/pisos-madrid/71',
#  'https://www.pisos.com/venta/pisos-madrid/72',
#  'https://www.pisos.com/venta/pisos-madrid/73',
#  'https://www.pisos.com/venta/pisos-madrid/74',
#  'https://www.pisos.com/venta/pisos-madrid/75',
#  'https://www.pisos.com/venta/pisos-madrid/76',
#  'https://www.pisos.com/venta/pisos-madrid/77',
#  'https://www.pisos.com/venta/pisos-madrid/78',
#  'https://www.pisos.com/venta/pisos-madrid/79',
#  'https://www.pisos.com/venta/pisos-madrid/80',
#  'https://www.pisos.com/venta/pisos-madrid/81',
#  'https://www.pisos.com/venta/pisos-madrid/82',
#  'https://www.pisos.com/venta/pisos-madrid/83',
#  'https://www.pisos.com/venta/pisos-madrid/84',
#  'https://www.pisos.com/venta/pisos-madrid/85',
#  'https://www.pisos.com/venta/pisos-madrid/86',
#  'https://www.pisos.com/venta/pisos-madrid/87',
#  'https://www.pisos.com/venta/pisos-madrid/88',
#  'https://www.pisos.com/venta/pisos-madrid/89',
#  'https://www.pisos.com/venta/pisos-madrid/90',
#  'https://www.pisos.com/venta/pisos-madrid/91',
#  'https://www.pisos.com/venta/pisos-madrid/92',
#  'https://www.pisos.com/venta/pisos-madrid/93',
#  'https://www.pisos.com/venta/pisos-madrid/94',
#  'https://www.pisos.com/venta/pisos-madrid/95',
#  'https://www.pisos.com/venta/pisos-madrid/96',
#  'https://www.pisos.com/venta/pisos-madrid/97',
#  'https://www.pisos.com/venta/pisos-madrid/98',
#  'https://www.pisos.com/venta/pisos-madrid/99',
#  'https://www.pisos.com/venta/pisos-madrid/100']

# %%
# Llenamos una lista con todos los enlaces a todos los pisos

urls_pisos = []

for enum, url in enumerate(urls_paginas[], 1):
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
    for ind, piso in enumerate(soup.find_all("div", class_ = "ad-preview__bottom"), 1):
        
        urls_pisos.append(piso.find("a")["href"])
        # print(f"Piso {ind} de la página {enum} TERMINADO")
        
    print(f"Página {enum} - TERMINADA")
#     print("-"*100)
        
    sleep(2)

# %%
urls_pisos[0]

# %%
def hacer_cadena(lista):
    cadena = ""
    for i in lista:
        if ":" in i:
            cadena = cadena + i + ". "
        else:
            cadena = cadena + i
    return cadena

# %%
titulos = []
zonas = []
construidos = []
# utiles = []
habitaciones = []
baños = []
plantas = []
# años = []
# estados = []
precios_metro_cuadrado = []
precios_venta = []
descripciones = []
datos_basicos = []
muebles_acabados = []
equip_instalaciones = []
exteriores = []

for enum, url in enumerate(urls_pisos, 1):
    
    response = requests.get(f"https://www.pisos.com{url}")
    soup = BeautifulSoup(response.text, "html.parser")
    
###################################################################################################################
    try:
        titulo = soup.find("h1", class_ = "title").text
    except:
        titulo = np.nan

###################################################################################################################
    try:
        zona = soup.find("h2", class_ = "position").text
    except:
        zona = np.nan

###################################################################################################################
    try:
        cons = soup.find("div", class_ = "basicdata-info").text.strip().split()[0]
    except:
        cons = np.nan

###################################################################################################################
#     try:
#         ut = 
#     except:
#         ut = np.nan

###################################################################################################################
    try:
        hab = soup.find("div", class_ = "basicdata-info").text.strip().split()[2]
    except:
        hab = np.nan

###################################################################################################################
    try:
        baño = soup.find("div", class_ = "basicdata-info").text.strip().split()[4]
    except:
        baño = np.nan

###################################################################################################################
    try:
        planta = soup.find("div", class_ = "basicdata-info").text.strip().split()[5][-2:]
    except:
        planta = np.nan

###################################################################################################################
#     try:
#         año = 
#     except:
#         año = np.nan
        
###################################################################################################################
#     try:
#         estado = 
#     except:
#         estado = np.nan

###################################################################################################################
    try:
        precio_m2 = soup.find("div", class_ = "basicdata-info").text.strip().split()[7]
    except:
        precio_m2 = np.nan

###################################################################################################################
    try:
        precio = soup.find("span", class_ = "h1 jsPrecioH1").text.split()[0]
    except:
        precio = np.nan

###################################################################################################################
    try:
        descripcion = soup.find("div", class_ = "description-container description-body").text.strip()
    except:
        descripcion = np.nan

###################################################################################################################
    try:
        datos = soup.find("ul", class_ = "charblock-list charblock-basics").text.strip().split("\n")
        datos = hacer_cadena(datos)
    except:
        datos = np.nan

###################################################################################################################
    try:
        acab = soup.find("li", class_ = "charblock-element element-with-bullet").text.strip().split("\n")
        acab = hacer_cadena(acab)
    except:
        acab = np.nan

###################################################################################################################
    try:
        inst = soup.find_all("div", class_ = "charblock-right")[2].text.strip().split("\n")
        inst = hacer_cadena(inst)
    except:
        inst = np.nan

###################################################################################################################
    try:
        ext = soup.find_all("div", class_ = "charblock-right")[3].text.strip().split("\n")
        ext = hacer_cadena(ext)
    except:
        ext = np.nan

###################################################################################################################

    titulos.append(titulo)
    zonas.append(zona)
    construidos.append(cons)
#     utiles.append(ut)
    habitaciones.append(hab)
    baños.append(baño)
    plantas.append(planta)
#     años.append(año)
#     estados.append(estado)
    precios_m2.append(precio_m2)
    precios_venta.append(precio)
    descripciones.append(descripcion)
    datos_basicos.append(datos)
    muebles_acabados.append(acab)
    equip_instalaciones.append(inst)
    exteriores.append(ext)
    
    print(f"Piso {enum} TERMINADO")
    print("-"*100)
    
    sleep(2)

# %%
df = pd.DataFrame()

df["Titulo"] = titulos
df["Zona"] = zonas
df["Metros Construidos"] = construidos
df["Habitaciones"] = habitaciones
df["Baños"] = baños
df["Planta"] = plantas
df["Precio x m2"] = precios_m2
df["Precio"] = precios_venta
df["Descripcion"] = descripciones
df["Informacion"] = datos_basicos
df["Acabados"] = muebles_acabados
df["Instalaciones"] = equip_instalaciones
df["Exteriores"] = exteriores

df
